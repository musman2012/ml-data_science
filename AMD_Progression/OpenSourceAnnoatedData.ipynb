# %% [markdown]
# <a href="https://colab.research.google.com/github/musman2012/ml-data_science/blob/master/AMD_Progression/OpenSourceAnnoatedData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install wget
import wget

wget.download('https://ucbeb3addcc14a897be1bdaea43f.dl.dropboxusercontent.com/zip_download_get/AcphZRljil_t2hBaQHpv68Lunx4kkl-xIAUV-ehyKzl_DNFc-pDfE_k35WqJunCwkca3MmI_PokckuOqEX-9uEFxBHctqpxK4AhWWECSVAr8RA?_download_id=9858253390205027307408400605378865041769501978867565578416072569&_notify_domain=www.dropbox.com&dl=1')
# Out:
# ...
# 'complementary_data.zip'

# %%
wget.download('https://ucdf8bda5460a28e9b35d76d3f5d.dl.dropboxusercontent.com/zip_download_get/AcpPPZ5mQUWTrvyNpY9ESlyNw76No3svkb8P538hCIBDqKCT9sYCjsLYGLlQT39PPj65V00at3vqjNHAxBn0np_IGc7mgmXSnOK2ioAYDAAHMw?_download_id=29998025354831714038728462502601293141134610278822150669953811675&_notify_domain=www.dropbox.com&dl=1')
# Out:
# 'AMD.zip'

# %%
#import tarfile
#with tarfile.open('/content/complementary_data.zip') as tar:
#    tar.extractall(path='Data')
import zipfile
with zipfile.ZipFile('/content/complementary_data.zip', 'r') as zip_ref:
    zip_ref.extractall(path='Data')

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import h5py
with h5py.File('/content/Data/Farsiu_Ophthalmology_2013_AMD_NSR_maps.mat', 'r') as f:
    print(f['AMD_NSR_maps'])
    #img = mpimg.imread(f['AMD_NSR_maps'])
    plt.imshow(f['AMD_NSR_maps'][2])
# Out:
# <HDF5 dataset "AMD_NSR_maps": shape (269, 1001, 1001), type "<f8">

# %%
wget.download('https://www.dropbox.com/sh/t0jz33utxlfi6op/AACdpRaUroDQllW9b8dCBKdFa?preview=Farsiu_Ophthalmology_2013_AMD_Subject_1002.mat')
# Out:
# 'AACdpRaUroDQllW9b8dCBKdFa'

# %%
with zipfile.ZipFile('/content/AMD.zip', 'r') as zip_ref:
    zip_ref.extractall(path='AMD')

# %%
with h5py.File('/content/AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1006.mat', 'r') as f:
    print(f.keys)
    #img = mpimg.imread(f['AMD_NSR_maps'])
    #plt.imshow(f['AMD_NSR_maps'][2])
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-29-086c2c47cbe2> in <module>()
# ----> 1 with h5py.File('/content/AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1006.mat', 'r') as f:
#       2     print(f.keys)
#       3     #img = mpimg.imread(f['AMD_NSR_maps'])
#       4     #plt.imshow(f['AMD_NSR_maps'][2])
#
# /usr/local/lib/python3.6/dist-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     406                 fid = make_fid(name, mode, userblock_size,
#     407                                fapl, fcpl=make_fcpl(track_order=track_order),
# --> 408                                swmr=swmr)
#     409
#     410             if isinstance(libver, tuple):
#
# ...

# %%
import scipy.io
f = scipy.io.loadmat('/content/AMD/Farsiu_Ophthalmology_2013_AMD_Subject_1056.mat')

# %%
f.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'images', 'layerMaps', 'Age'])

# %%
import numpy as np
plt.imshow(np.transpose(f['images'][1]))

# %%
plt.imshow(f['layerMaps'])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
